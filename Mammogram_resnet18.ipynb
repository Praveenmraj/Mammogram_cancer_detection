# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES
# TO THE CORRECT LOCATION (/kaggle/input) IN YOUR NOTEBOOK,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

import os
import sys
from tempfile import NamedTemporaryFile
from urllib.request import urlopen
from urllib.parse import unquote, urlparse
from urllib.error import HTTPError
from zipfile import ZipFile
import tarfile
import shutil

CHUNK_SIZE = 40960
DATA_SOURCE_MAPPING = 'breast-ultrasound-images-dataset:https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-data-sets%2F1209633%2F2021025%2Fbundle%2Farchive.zip%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com%252F20240509%252Fauto%252Fstorage%252Fgoog4_request%26X-Goog-Date%3D20240509T062447Z%26X-Goog-Expires%3D259200%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...'

KAGGLE_INPUT_PATH='/kaggle/input'
KAGGLE_WORKING_PATH='/kaggle/working'
KAGGLE_SYMLINK='kaggle'

# !umount /kaggle/input/ 2> /dev/null
shutil.rmtree('/kaggle/input', ignore_errors=True)
os.makedirs(KAGGLE_INPUT_PATH, 0o777, exist_ok=True)
os.makedirs(KAGGLE_WORKING_PATH, 0o777, exist_ok=True)

try:
  os.symlink(KAGGLE_INPUT_PATH, os.path.join("..", 'input'), target_is_directory=True)
except FileExistsError:
  pass
try:
  os.symlink(KAGGLE_WORKING_PATH, os.path.join("..", 'working'), target_is_directory=True)
except FileExistsError:
  pass

for data_source_mapping in DATA_SOURCE_MAPPING.split(','):
    directory, download_url_encoded = data_source_mapping.split(':')
    download_url = unquote(download_url_encoded)
    filename = urlparse(download_url).path
    destination_path = os.path.join(KAGGLE_INPUT_PATH, directory)
    try:
        with urlopen(download_url) as fileres, NamedTemporaryFile() as tfile:
            total_length = fileres.headers['content-length']
            print(f'Downloading {directory}, {total_length} bytes compressed')
            dl = 0
            data = fileres.read(CHUNK_SIZE)
            while len(data) > 0:
                dl += len(data)
                tfile.write(data)
                done = int(50 * dl / int(total_length))
                sys.stdout.write(f"\r[{'=' * done}{' ' * (50-done)}] {dl} bytes downloaded")
                sys.stdout.flush()
                data = fileres.read(CHUNK_SIZE)
            if filename.endswith('.zip'):
              with ZipFile(tfile) as zfile:
                zfile.extractall(destination_path)
            else:
              with tarfile.open(tfile.name) as tarfile:
                tarfile.extractall(destination_path)
            print(f'\nDownloaded and uncompressed: {directory}')
    except HTTPError as e:
        print(f'Failed to load (likely expired) {download_url} to path {destination_path}')
        continue
    except OSError as e:
        print(f'Failed to load {download_url} to path {destination_path}')
        continue

print('Data source import complete.')
# Out:
# Downloading breast-ultrasound-images-dataset, 204421470 bytes compressed
# [==================================================] 204421470 bytes downloaded
# Downloaded and uncompressed: breast-ultrasound-images-dataset
# Data source import complete.

# %%
import numpy as np # linear algebra
import os

# %% [markdown]
# DATASET

# %%
BASE_PATH = '/kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT'
unique_classes = []
for path in os.listdir(BASE_PATH):
    unique_classes.append(path)
print(unique_classes)
# Out:
# ['benign', 'normal', 'malignant']

# %%
class_index = [unique_classes[1], unique_classes[0], unique_classes[2]]
for c in class_index:
    print(c, "-", class_index.index(c))
# Out:
# normal - 0
# benign - 1
# malignant - 2

# %% [markdown]
# LOADING IMAGES AND MASKS PATHS

# %%
images = []
masks = []
labels = []
for folder in os.listdir(BASE_PATH):
    class_path = os.path.join(BASE_PATH, folder)
    for img in os.listdir(class_path):
        if "_mask" not in img:
            img_path = os.path.join(class_path, img)
            msk_path = img_path.replace(".png", "_mask.png")
            # check if mask exist
            if os.path.exists(msk_path):
                images.append(img_path)
                masks.append(msk_path)
                labels.append(folder)

# %%
print(len(images))
# Out:
# 780

# %%
images[0]
# Out:
# '/kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (415).png'

# %%
input_images_size = 256
channel = 1

# %% [markdown]
# DATA LOADING AND PREPROCESSING

# %%
import cv2
import scipy
import scipy.ndimage


def load_image(img_path):
    """ Load single image as Grayscale
    """
    # load image as grayscale
    img = cv2.imread(img_path, 0)
    return img

def padding(img, msk):
    """ Pad images to make them square
    """
    size = np.max(img.shape)

    offset_x = (size-img.shape[0])//2
    offset_y = (size-img.shape[1])//2

    blank_image = np.zeros((size, size))
    blank_mask = np.zeros((size, size))

    blank_image[offset_x:offset_x+img.shape[0],
               offset_y:offset_y+img.shape[1]] = img
    blank_mask[offset_x:offset_x+img.shape[0],
               offset_y:offset_y+img.shape[1]] = msk
    return blank_image, blank_mask

def resize_mask(mask):
    """Resize mask, its different because mask pixel value can change because of resize
    """
    new_size = np.array([input_images_size, input_images_size]) / mask.shape
    mask = scipy.ndimage.interpolation.zoom(mask, new_size)
    return mask

def resize(img):
    """Resize image
    """
    img = cv2.resize(img, (input_images_size, input_images_size))
    return img

def preprocess(img):
    """Image preprocessing
    Normalize image
    """
    img = img/255.0
    return img

def inverse_preprocess(img):
    """Inverse of preprocessing
    """
    img = img*255
    return img

def load_data(img_path, msk_path, label):
    """Load image, mask and repalce mask value with class index
    0 = normal
    1 = benign
    2 = malignant
    """
    img = load_image(img_path)
    msk = load_image(msk_path)
    img, msk = padding(img, msk)
    label_indx = class_index.index(label)
    msk[msk == 255] = 1
    msk = msk.astype("uint8")
    img = resize(img)
    msk = resize_mask(msk)
    new_mask = np.zeros((input_images_size, input_images_size, 2))
    if label_indx != 0:
        new_mask[:, :, label_indx-1] = msk
#     print(np.unique(msk), label, label_indx)
    return img, new_mask

def load_batch(images, masks, labels):
    """Load Batch of data
    """
    batch_x = []
    batch_y = []
    for i, m, l in zip(images, masks, labels):
        img, msk = load_data(i, m, l)
        img = preprocess(img)
        batch_x.append(img)
        batch_y.append(msk)
    return np.array(batch_x), np.array(batch_y)

# %%
import matplotlib.pyplot as plt
for i in [0, 500, 600]:
    indx = i
    img, msk = load_data(images[indx], masks[indx], labels[indx])
    print(np.min(img), np.max(img), img.shape)
    plt.figure(figsize=(20, 20))
    plt.subplot(1, 3, 1)
    plt.axis("off")
    plt.imshow(img)
    plt.title('Image')
    plt.subplot(1, 3, 2)
    plt.axis("off")
    plt.imshow(msk[:, :, 0])
    plt.title('Benign')
    plt.subplot(1, 3, 3)
    plt.axis("off")
    plt.imshow(msk[:, :, 1])
    plt.title('Malignant')
    plt.show()
# Out:
# <ipython-input-9-1e523946cf1c>:34: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   mask = scipy.ndimage.interpolation.zoom(mask, new_size)
# 0.0 254.541015625 (256, 256)
# 0.0 252.98455810546875 (256, 256)
# 0.0 254.4249267578125 (256, 256)

# %%
images = np.array(images)
masks = np.array(masks)
labels = np.array(labels)

# %% [markdown]
# MODEL

# %%
# !pip install segmentation_models
# Out:
# Requirement already satisfied: segmentation_models in /usr/local/lib/python3.10/dist-packages (1.0.1)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in /usr/local/lib/python3.10/dist-packages (from segmentation_models) (1.0.8)
# Requirement already satisfied: image-classifiers==1.0.0 in /usr/local/lib/python3.10/dist-packages (from segmentation_models) (1.0.0)
# Requirement already satisfied: efficientnet==1.0.0 in /usr/local/lib/python3.10/dist-packages (from segmentation_models) (1.0.0)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from efficientnet==1.0.0->segmentation_models) (0.19.3)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation_models) (1.25.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation_models) (3.9.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (1.11.4)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (3.3)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (9.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (2024.5.3)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (1.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (24.0)

# %%
import segmentation_models as sm
import tensorflow as tf

# Set the framework to 'tf.keras' if it's not already set
sm.set_framework('tf.keras')

# Define input parameters
BACKBONE = 'resnet18'  # EfficientNetB1 backbone
LR = 0.00001
input_images_size = 256  # Assuming a specific input size
channel = 3  # Assuming RGB images

# Load the EfficientNetB1-based UNet model
model = sm.Unet(BACKBONE, classes=2, activation="sigmoid",
                input_shape=(input_images_size, input_images_size, channel),
                encoder_weights=None)

optim = tf.keras.optimizers.Adam(LR)

dice_loss = sm.losses.DiceLoss()
focal_loss = sm.losses.BinaryFocalLoss()
total_loss = dice_loss + (1 * focal_loss)

metrics = [sm.metrics.IOUScore(threshold=0.5),
           sm.metrics.FScore(threshold=0.5)]

model.compile(optim, total_loss, metrics)
# Out:
# Segmentation Models: using `keras` framework.

# %% [markdown]
# TRAINING

# %%
import segmentation_models as sm
import tensorflow as tf
import numpy as np

sm.set_framework('tf.keras')

BACKBONE = 'resnet18'  # Change the backbone to VGG16
LR = 0.00001
input_images_size = 256  # Assuming a specific input size
channel = 1  # Assuming single-channel images

# Load the VGG16-based UNet model
model = sm.Unet(BACKBONE, classes=2, activation="sigmoid",
                input_shape=(input_images_size, input_images_size, channel),
                encoder_weights=None)

optim = tf.keras.optimizers.Adam(LR)

dice_loss = sm.losses.DiceLoss()
focal_loss = sm.losses.BinaryFocalLoss()
total_loss = dice_loss + (1 * focal_loss)

metrics = [sm.metrics.IOUScore(threshold=0.5),
           sm.metrics.FScore(threshold=0.5)]

model.compile(optim, total_loss, metrics)

# Assuming you have defined images, masks, and labels appropriately

batch_size = 4
history = {"epoch": []}
for e in range(11):
    print("epoch:", e, end=" > ")
    indexes = list(range(len(images)))
    temp_history = {"loss": [], "IOU": [], "F-Score": []}
    for b in range(0, len(images), batch_size):
        bs = b
        be = bs + batch_size
        batch_index = indexes[bs:be]
        batch_x, batch_y = load_batch(images[batch_index], masks[batch_index], labels[batch_index])
        batch_x = np.expand_dims(batch_x, axis=-1)
        batch_y = np.expand_dims(batch_y, axis=-1)
        batch_y = batch_y.astype("float32")
        loss = model.train_on_batch(batch_x, batch_y)
        temp_history["loss"].append(loss[0])
        temp_history["IOU"].append(loss[1])
        temp_history["F-Score"].append(loss[2])
    print("loss", np.round(np.mean(temp_history["loss"]), 4),
          "IOU", np.round(np.mean(temp_history["IOU"]), 4),
          "F-Score", np.round(np.mean(temp_history["F-Score"]), 4))
    history["epoch"].append(temp_history)

model.save_weights("mammogram_cancer_segmentation_resnet18")
# Out:
# epoch: 0 >
# <ipython-input-9-1e523946cf1c>:34: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   mask = scipy.ndimage.interpolation.zoom(mask, new_size)
# loss 1.2162 IOU 0.0204 F-Score 0.0382
# epoch: 1 > loss 1.0974 IOU 0.0191 F-Score 0.0357
# epoch: 2 > loss 1.0483 IOU 0.0222 F-Score 0.0408
# epoch: 3 > loss 1.0242 IOU 0.0307 F-Score 0.0545
# epoch: 4 > loss 1.0064 IOU 0.0462 F-Score 0.0777
# epoch: 5 > loss 0.9907 IOU 0.0728 F-Score 0.1127
# epoch: 6 > loss 0.9752 IOU 0.1091 F-Score 0.156
# epoch: 7 > loss 0.9602 IOU 0.1543 F-Score 0.211
# epoch: 8 > loss 0.9461 IOU 0.2091 F-Score 0.2696
# epoch: 9 > loss 0.9315 IOU 0.2444 F-Score 0.302
# epoch: 10 > loss 0.9174 IOU 0.2673 F-Score 0.3213

# %% [markdown]
# TESTING

# %%
import matplotlib.pyplot as plt
for i in [0, 500, 600]:
    indx = i
    img, msk = load_data(images[indx], masks[indx], labels[indx])
    print(np.min(img), np.max(img), img.shape)
    print(img.shape)

    img2 = preprocess(img)
    pred = model.predict(np.array([img2]))
    pred = pred[0]

    plt.figure(figsize=(20, 20))
    plt.subplot(1, 3, 1)
    plt.axis("off")
    plt.imshow(img)
    plt.subplot(1, 3, 2)
    plt.axis("off")
    plt.imshow(pred[:, :, 0])
    plt.subplot(1, 3, 3)
    plt.axis("off")
    plt.imshow(pred[:, :, 1])
    plt.show()
# Out:
# <ipython-input-9-1e523946cf1c>:34: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   mask = scipy.ndimage.interpolation.zoom(mask, new_size)
# 0.0 254.541015625 (256, 256)
# (256, 256)
# 1/1 [==============================] - 1s 751ms/step
# 0.0 252.98455810546875 (256, 256)
# (256, 256)
# 1/1 [==============================] - 0s 293ms/step
# 0.0 254.4249267578125 (256, 256)
# (256, 256)
# 1/1 [==============================] - 0s 267ms/step

# %%
model.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  data (InputLayer)           [(None, 256, 256, 1)]        0         []
#
#  bn_data (BatchNormalizatio  (None, 256, 256, 1)          3         ['data[0][0]']
#  n)
#
#  zero_padding2d_36 (ZeroPad  (None, 262, 262, 1)          0         ['bn_data[0][0]']
#  ding2D)
#
#  conv0 (Conv2D)              (None, 128, 128, 64)         3136      ['zero_padding2d_36[0][0]']
#
#  bn0 (BatchNormalization)    (None, 128, 128, 64)         256       ['conv0[0][0]']
#
#  relu0 (Activation)          (None, 128, 128, 64)         0         ['bn0[0][0]']
#
#  zero_padding2d_37 (ZeroPad  (None, 130, 130, 64)         0         ['relu0[0][0]']
#  ding2D)
#
#  pooling0 (MaxPooling2D)     (None, 64, 64, 64)           0         ['zero_padding2d_37[0][0]']
#
#  stage1_unit1_bn1 (BatchNor  (None, 64, 64, 64)           256       ['pooling0[0][0]']
#  malization)
#
#  stage1_unit1_relu1 (Activa  (None, 64, 64, 64)           0         ['stage1_unit1_bn1[0][0]']
#  tion)
#
#  zero_padding2d_38 (ZeroPad  (None, 66, 66, 64)           0         ['stage1_unit1_relu1[0][0]']
#  ding2D)
#
#  stage1_unit1_conv1 (Conv2D  (None, 64, 64, 64)           36864     ['zero_padding2d_38[0][0]']
#  )
#
#  stage1_unit1_bn2 (BatchNor  (None, 64, 64, 64)           256       ['stage1_unit1_conv1[0][0]']
#  malization)
#
#  stage1_unit1_relu2 (Activa  (None, 64, 64, 64)           0         ['stage1_unit1_bn2[0][0]']
#  tion)
#
#  zero_padding2d_39 (ZeroPad  (None, 66, 66, 64)           0         ['stage1_unit1_relu2[0][0]']
#  ding2D)
#
#  stage1_unit1_conv2 (Conv2D  (None, 64, 64, 64)           36864     ['zero_padding2d_39[0][0]']
#  )
#
#  stage1_unit1_sc (Conv2D)    (None, 64, 64, 64)           4096      ['stage1_unit1_relu1[0][0]']
#
#  add_16 (Add)                (None, 64, 64, 64)           0         ['stage1_unit1_conv2[0][0]',
#                                                                      'stage1_unit1_sc[0][0]']
#
#  stage1_unit2_bn1 (BatchNor  (None, 64, 64, 64)           256       ['add_16[0][0]']
#  malization)
#
#  stage1_unit2_relu1 (Activa  (None, 64, 64, 64)           0         ['stage1_unit2_bn1[0][0]']
#  tion)
#
#  zero_padding2d_40 (ZeroPad  (None, 66, 66, 64)           0         ['stage1_unit2_relu1[0][0]']
#  ding2D)
#
#  stage1_unit2_conv1 (Conv2D  (None, 64, 64, 64)           36864     ['zero_padding2d_40[0][0]']
#  )
#
#  stage1_unit2_bn2 (BatchNor  (None, 64, 64, 64)           256       ['stage1_unit2_conv1[0][0]']
#  malization)
#
#  stage1_unit2_relu2 (Activa  (None, 64, 64, 64)           0         ['stage1_unit2_bn2[0][0]']
#  tion)
#
#  zero_padding2d_41 (ZeroPad  (None, 66, 66, 64)           0         ['stage1_unit2_relu2[0][0]']
#  ding2D)
#
#  stage1_unit2_conv2 (Conv2D  (None, 64, 64, 64)           36864     ['zero_padding2d_41[0][0]']
#  )
#
#  add_17 (Add)                (None, 64, 64, 64)           0         ['stage1_unit2_conv2[0][0]',
#                                                                      'add_16[0][0]']
#
#  stage2_unit1_bn1 (BatchNor  (None, 64, 64, 64)           256       ['add_17[0][0]']
#  malization)
#
#  stage2_unit1_relu1 (Activa  (None, 64, 64, 64)           0         ['stage2_unit1_bn1[0][0]']
#  tion)
#
#  zero_padding2d_42 (ZeroPad  (None, 66, 66, 64)           0         ['stage2_unit1_relu1[0][0]']
#  ding2D)
#
#  stage2_unit1_conv1 (Conv2D  (None, 32, 32, 128)          73728     ['zero_padding2d_42[0][0]']
#  )
#
#  stage2_unit1_bn2 (BatchNor  (None, 32, 32, 128)          512       ['stage2_unit1_conv1[0][0]']
#  malization)
#
#  stage2_unit1_relu2 (Activa  (None, 32, 32, 128)          0         ['stage2_unit1_bn2[0][0]']
#  tion)
#
#  zero_padding2d_43 (ZeroPad  (None, 34, 34, 128)          0         ['stage2_unit1_relu2[0][0]']
#  ding2D)
#
#  stage2_unit1_conv2 (Conv2D  (None, 32, 32, 128)          147456    ['zero_padding2d_43[0][0]']
#  )
#
#  stage2_unit1_sc (Conv2D)    (None, 32, 32, 128)          8192      ['stage2_unit1_relu1[0][0]']
#
#  add_18 (Add)                (None, 32, 32, 128)          0         ['stage2_unit1_conv2[0][0]',
#                                                                      'stage2_unit1_sc[0][0]']
#
#  stage2_unit2_bn1 (BatchNor  (None, 32, 32, 128)          512       ['add_18[0][0]']
#  malization)
#
#  stage2_unit2_relu1 (Activa  (None, 32, 32, 128)          0         ['stage2_unit2_bn1[0][0]']
#  tion)
#
#  zero_padding2d_44 (ZeroPad  (None, 34, 34, 128)          0         ['stage2_unit2_relu1[0][0]']
#  ding2D)
#
#  stage2_unit2_conv1 (Conv2D  (None, 32, 32, 128)          147456    ['zero_padding2d_44[0][0]']
#  )
#
#  stage2_unit2_bn2 (BatchNor  (None, 32, 32, 128)          512       ['stage2_unit2_conv1[0][0]']
#  malization)
#
#  stage2_unit2_relu2 (Activa  (None, 32, 32, 128)          0         ['stage2_unit2_bn2[0][0]']
#  tion)
#
#  zero_padding2d_45 (ZeroPad  (None, 34, 34, 128)          0         ['stage2_unit2_relu2[0][0]']
#  ding2D)
#
#  stage2_unit2_conv2 (Conv2D  (None, 32, 32, 128)          147456    ['zero_padding2d_45[0][0]']
#  )
#
#  add_19 (Add)                (None, 32, 32, 128)          0         ['stage2_unit2_conv2[0][0]',
#                                                                      'add_18[0][0]']
#
#  stage3_unit1_bn1 (BatchNor  (None, 32, 32, 128)          512       ['add_19[0][0]']
#  malization)
#
#  stage3_unit1_relu1 (Activa  (None, 32, 32, 128)          0         ['stage3_unit1_bn1[0][0]']
#  tion)
#
#  zero_padding2d_46 (ZeroPad  (None, 34, 34, 128)          0         ['stage3_unit1_relu1[0][0]']
#  ding2D)
#
#  stage3_unit1_conv1 (Conv2D  (None, 16, 16, 256)          294912    ['zero_padding2d_46[0][0]']
#  )
#
#  stage3_unit1_bn2 (BatchNor  (None, 16, 16, 256)          1024      ['stage3_unit1_conv1[0][0]']
#  malization)
#
#  stage3_unit1_relu2 (Activa  (None, 16, 16, 256)          0         ['stage3_unit1_bn2[0][0]']
#  tion)
#
#  zero_padding2d_47 (ZeroPad  (None, 18, 18, 256)          0         ['stage3_unit1_relu2[0][0]']
#  ding2D)
#
#  stage3_unit1_conv2 (Conv2D  (None, 16, 16, 256)          589824    ['zero_padding2d_47[0][0]']
#  )
#
#  stage3_unit1_sc (Conv2D)    (None, 16, 16, 256)          32768     ['stage3_unit1_relu1[0][0]']
#
#  add_20 (Add)                (None, 16, 16, 256)          0         ['stage3_unit1_conv2[0][0]',
#                                                                      'stage3_unit1_sc[0][0]']
#
#  stage3_unit2_bn1 (BatchNor  (None, 16, 16, 256)          1024      ['add_20[0][0]']
#  malization)
#
#  stage3_unit2_relu1 (Activa  (None, 16, 16, 256)          0         ['stage3_unit2_bn1[0][0]']
#  tion)
#
#  zero_padding2d_48 (ZeroPad  (None, 18, 18, 256)          0         ['stage3_unit2_relu1[0][0]']
#  ding2D)
#
#  stage3_unit2_conv1 (Conv2D  (None, 16, 16, 256)          589824    ['zero_padding2d_48[0][0]']
#  )
#
#  stage3_unit2_bn2 (BatchNor  (None, 16, 16, 256)          1024      ['stage3_unit2_conv1[0][0]']
#  malization)
#
#  stage3_unit2_relu2 (Activa  (None, 16, 16, 256)          0         ['stage3_unit2_bn2[0][0]']
#  tion)
#
#  zero_padding2d_49 (ZeroPad  (None, 18, 18, 256)          0         ['stage3_unit2_relu2[0][0]']
#  ding2D)
#
#  stage3_unit2_conv2 (Conv2D  (None, 16, 16, 256)          589824    ['zero_padding2d_49[0][0]']
#  )
#
#  add_21 (Add)                (None, 16, 16, 256)          0         ['stage3_unit2_conv2[0][0]',
#                                                                      'add_20[0][0]']
#
#  stage4_unit1_bn1 (BatchNor  (None, 16, 16, 256)          1024      ['add_21[0][0]']
#  malization)
#
#  stage4_unit1_relu1 (Activa  (None, 16, 16, 256)          0         ['stage4_unit1_bn1[0][0]']
#  tion)
#
#  zero_padding2d_50 (ZeroPad  (None, 18, 18, 256)          0         ['stage4_unit1_relu1[0][0]']
#  ding2D)
#
#  stage4_unit1_conv1 (Conv2D  (None, 8, 8, 512)            1179648   ['zero_padding2d_50[0][0]']
#  )
#
#  stage4_unit1_bn2 (BatchNor  (None, 8, 8, 512)            2048      ['stage4_unit1_conv1[0][0]']
#  malization)
#
#  stage4_unit1_relu2 (Activa  (None, 8, 8, 512)            0         ['stage4_unit1_bn2[0][0]']
#  tion)
#
#  zero_padding2d_51 (ZeroPad  (None, 10, 10, 512)          0         ['stage4_unit1_relu2[0][0]']
#  ding2D)
#
#  stage4_unit1_conv2 (Conv2D  (None, 8, 8, 512)            2359296   ['zero_padding2d_51[0][0]']
#  )
#
#  stage4_unit1_sc (Conv2D)    (None, 8, 8, 512)            131072    ['stage4_unit1_relu1[0][0]']
#
#  add_22 (Add)                (None, 8, 8, 512)            0         ['stage4_unit1_conv2[0][0]',
#                                                                      'stage4_unit1_sc[0][0]']
#
#  stage4_unit2_bn1 (BatchNor  (None, 8, 8, 512)            2048      ['add_22[0][0]']
#  malization)
#
#  stage4_unit2_relu1 (Activa  (None, 8, 8, 512)            0         ['stage4_unit2_bn1[0][0]']
#  tion)
#
#  zero_padding2d_52 (ZeroPad  (None, 10, 10, 512)          0         ['stage4_unit2_relu1[0][0]']
#  ding2D)
#
#  stage4_unit2_conv1 (Conv2D  (None, 8, 8, 512)            2359296   ['zero_padding2d_52[0][0]']
#  )
#
#  stage4_unit2_bn2 (BatchNor  (None, 8, 8, 512)            2048      ['stage4_unit2_conv1[0][0]']
#  malization)
#
#  stage4_unit2_relu2 (Activa  (None, 8, 8, 512)            0         ['stage4_unit2_bn2[0][0]']
#  tion)
#
#  zero_padding2d_53 (ZeroPad  (None, 10, 10, 512)          0         ['stage4_unit2_relu2[0][0]']
#  ding2D)
#
#  stage4_unit2_conv2 (Conv2D  (None, 8, 8, 512)            2359296   ['zero_padding2d_53[0][0]']
#  )
#
#  add_23 (Add)                (None, 8, 8, 512)            0         ['stage4_unit2_conv2[0][0]',
#                                                                      'add_22[0][0]']
#
#  bn1 (BatchNormalization)    (None, 8, 8, 512)            2048      ['add_23[0][0]']
#
#  relu1 (Activation)          (None, 8, 8, 512)            0         ['bn1[0][0]']
#
#  decoder_stage0_upsampling   (None, 16, 16, 512)          0         ['relu1[0][0]']
#  (UpSampling2D)
#
#  decoder_stage0_concat (Con  (None, 16, 16, 768)          0         ['decoder_stage0_upsampling[0]
#  catenate)                                                          [0]',
#                                                                      'stage4_unit1_relu1[0][0]']
#
#  decoder_stage0a_conv (Conv  (None, 16, 16, 256)          1769472   ['decoder_stage0_concat[0][0]'
#  2D)                                                                ]
#
#  decoder_stage0a_bn (BatchN  (None, 16, 16, 256)          1024      ['decoder_stage0a_conv[0][0]']
#  ormalization)
#
#  decoder_stage0a_relu (Acti  (None, 16, 16, 256)          0         ['decoder_stage0a_bn[0][0]']
#  vation)
#
#  decoder_stage0b_conv (Conv  (None, 16, 16, 256)          589824    ['decoder_stage0a_relu[0][0]']
#  2D)
#
#  decoder_stage0b_bn (BatchN  (None, 16, 16, 256)          1024      ['decoder_stage0b_conv[0][0]']
#  ormalization)
#
#  decoder_stage0b_relu (Acti  (None, 16, 16, 256)          0         ['decoder_stage0b_bn[0][0]']
#  vation)
#
#  decoder_stage1_upsampling   (None, 32, 32, 256)          0         ['decoder_stage0b_relu[0][0]']
#  (UpSampling2D)
#
#  decoder_stage1_concat (Con  (None, 32, 32, 384)          0         ['decoder_stage1_upsampling[0]
#  catenate)                                                          [0]',
#                                                                      'stage3_unit1_relu1[0][0]']
#
#  decoder_stage1a_conv (Conv  (None, 32, 32, 128)          442368    ['decoder_stage1_concat[0][0]'
#  2D)                                                                ]
#
#  decoder_stage1a_bn (BatchN  (None, 32, 32, 128)          512       ['decoder_stage1a_conv[0][0]']
#  ormalization)
#
#  decoder_stage1a_relu (Acti  (None, 32, 32, 128)          0         ['decoder_stage1a_bn[0][0]']
#  vation)
#
#  decoder_stage1b_conv (Conv  (None, 32, 32, 128)          147456    ['decoder_stage1a_relu[0][0]']
#  2D)
#
#  decoder_stage1b_bn (BatchN  (None, 32, 32, 128)          512       ['decoder_stage1b_conv[0][0]']
#  ormalization)
#
#  decoder_stage1b_relu (Acti  (None, 32, 32, 128)          0         ['decoder_stage1b_bn[0][0]']
#  vation)
#
#  decoder_stage2_upsampling   (None, 64, 64, 128)          0         ['decoder_stage1b_relu[0][0]']
#  (UpSampling2D)
#
#  decoder_stage2_concat (Con  (None, 64, 64, 192)          0         ['decoder_stage2_upsampling[0]
#  catenate)                                                          [0]',
#                                                                      'stage2_unit1_relu1[0][0]']
#
#  decoder_stage2a_conv (Conv  (None, 64, 64, 64)           110592    ['decoder_stage2_concat[0][0]'
#  2D)                                                                ]
#
#  decoder_stage2a_bn (BatchN  (None, 64, 64, 64)           256       ['decoder_stage2a_conv[0][0]']
#  ormalization)
#
#  decoder_stage2a_relu (Acti  (None, 64, 64, 64)           0         ['decoder_stage2a_bn[0][0]']
#  vation)
#
#  decoder_stage2b_conv (Conv  (None, 64, 64, 64)           36864     ['decoder_stage2a_relu[0][0]']
#  2D)
#
#  decoder_stage2b_bn (BatchN  (None, 64, 64, 64)           256       ['decoder_stage2b_conv[0][0]']
#  ormalization)
#
#  decoder_stage2b_relu (Acti  (None, 64, 64, 64)           0         ['decoder_stage2b_bn[0][0]']
#  vation)
#
#  decoder_stage3_upsampling   (None, 128, 128, 64)         0         ['decoder_stage2b_relu[0][0]']
#  (UpSampling2D)
#
#  decoder_stage3_concat (Con  (None, 128, 128, 128)        0         ['decoder_stage3_upsampling[0]
#  catenate)                                                          [0]',
#                                                                      'relu0[0][0]']
#
#  decoder_stage3a_conv (Conv  (None, 128, 128, 32)         36864     ['decoder_stage3_concat[0][0]'
#  2D)                                                                ]
#
#  decoder_stage3a_bn (BatchN  (None, 128, 128, 32)         128       ['decoder_stage3a_conv[0][0]']
#  ormalization)
#
#  decoder_stage3a_relu (Acti  (None, 128, 128, 32)         0         ['decoder_stage3a_bn[0][0]']
#  vation)
#
#  decoder_stage3b_conv (Conv  (None, 128, 128, 32)         9216      ['decoder_stage3a_relu[0][0]']
#  2D)
#
#  decoder_stage3b_bn (BatchN  (None, 128, 128, 32)         128       ['decoder_stage3b_conv[0][0]']
#  ormalization)
#
#  decoder_stage3b_relu (Acti  (None, 128, 128, 32)         0         ['decoder_stage3b_bn[0][0]']
#  vation)
#
#  decoder_stage4_upsampling   (None, 256, 256, 32)         0         ['decoder_stage3b_relu[0][0]']
#  (UpSampling2D)
#
#  decoder_stage4a_conv (Conv  (None, 256, 256, 16)         4608      ['decoder_stage4_upsampling[0]
#  2D)                                                                [0]']
#
#  decoder_stage4a_bn (BatchN  (None, 256, 256, 16)         64        ['decoder_stage4a_conv[0][0]']
#  ormalization)
#
#  decoder_stage4a_relu (Acti  (None, 256, 256, 16)         0         ['decoder_stage4a_bn[0][0]']
#  vation)
#
#  decoder_stage4b_conv (Conv  (None, 256, 256, 16)         2304      ['decoder_stage4a_relu[0][0]']
#  2D)
#
#  decoder_stage4b_bn (BatchN  (None, 256, 256, 16)         64        ['decoder_stage4b_conv[0][0]']
#  ormalization)
#
#  decoder_stage4b_relu (Acti  (None, 256, 256, 16)         0         ['decoder_stage4b_bn[0][0]']
#  vation)
#
#  final_conv (Conv2D)         (None, 256, 256, 2)          290       ['decoder_stage4b_relu[0][0]']
#
#  sigmoid (Activation)        (None, 256, 256, 2)          0         ['final_conv[0][0]']
#
# ==================================================================================================
# Total params: 14334437 (54.68 MB)
# Trainable params: 14324515 (54.64 MB)
# Non-trainable params: 9922 (38.76 KB)
# __________________________________________________________________________________________________

# %%
import numpy as np

def extract_labels(predicted_masks, threshold=0.5):
    # Example extract_labels function for binary classification
    binary_masks = (predicted_masks > threshold).astype(np.uint8)
    predicted_labels = np.zeros(binary_masks.shape[:-1], dtype=np.uint8)
    predicted_labels[binary_masks[..., 0] == 1] = 1  # Assuming class 0 for positive prediction
    return predicted_labels

# Example: Assuming you have validation labels stored in validation_labels
validation_labels = np.array([1, 1, 1, 0, 1, 0, 0, 1])  # Example validation labels
# Example: Assuming you have obtained predicted_masks from your model
predicted_masks = np.random.rand(256)  # Example predicted masks with two classes

# Calculate predicted labels using extract_labels
predicted_labels = extract_labels(predicted_masks)

# Flatten the predicted_labels to match the shape of validation_labels
predicted_labels_flat = predicted_labels.flatten()

# Calculate accuracy
accuracy = np.mean(validation_labels == predicted_labels_flat)

print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.625
